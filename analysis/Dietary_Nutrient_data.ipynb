# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick
# Export to DataBase
from sqlalchemy import create_engine, types


import warnings
warnings.filterwarnings("ignore")

# %%
from dotenv import dotenv_values

config = dotenv_values()

# define variables for the login
pg_user = config['POSTGRES_USER']  # align the key label with your .env file !
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# Now building the URL with the values from the .env file
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

engine = create_engine(url, echo=False)

# %% [markdown]
# ## Dietary Nutrient Intake data for Day 01

# %%
# Exporting the Dietary Nutrients intake day  data
df_dietary_nutrient_intake_day_01 = pd.read_sas('F:\Susanna Course\Capstone_data\DR1TOT_L.xpt', format="xport", encoding="utf-8")

# %%
# List of relevant nutrient columns which could potentially be insightful to the research question
nutrient_columns = [
    'SEQN',
    'DR1TKCAL', 'DR1TPROT', 'DR1TCARB','DR1TSUGR','DR1TFIBE', 'DR1TTFAT',
     'DR1TSFAT','DR1TMFAT','DR1TPFAT','DR1TCHOL','DR1TSODI','DR1TPOTA','DR1TMOIS',
    'DR1TVC','DR1TVD','DR1TVK','DR1TCALC'
    ]

# %%
# Filter the dataframe to keep only the relevant columns
df_nutrients_day01 = df_dietary_nutrient_intake_day_01[nutrient_columns]

# %%
# Rename columns
df_nutrients_day01  = df_nutrients_day01.rename(
    columns={'SEQN': 'seqn_no',
             'DR1TKCAL':'energy_kcal','DR1TPROT':'protein_gms','DR1TCARB':'carbohydrate_gms','DR1TTFAT':'total_fats_gms',
             'DR1TSUGR': 'total_sugars_gms','DR1TFIBE':'dietary_fiber_gms','DR1TSFAT':'saturated_fats_gms', 'DR1TMFAT':'mono_saturated_fats_gms',
             'DR1TPFAT':'poly_unsaturated_fats_gms','DR1TCHOL':'cholestrol_gms','DR1TCALC':'calcium_mg',
             'DR1TSODI':'sodium_mg','DR1TPOTA':'potassium_mg','DR1TCAFF':'caffeine_mg','DR1TALCO':'alcohol_gms',
              'DR1TMOIS':'moisture_gms','DR1TVC':'vitaminC_mg','DR1TVD':'vitaminD_mcg','DR1TVK':'vitaK_mcg'})

# %%
# Now changing the data type of 'seqn_no' to int
df_nutrients_day01['seqn_no'] = df_nutrients_day01['seqn_no'].astype(int)

# %% [markdown]
# Saving as csv file into data/dietary_data

# %%
#export as csv

file_path = "../data/dietary_data/dietary_nutrient_data_01.csv" 

try:
    df_nutrients_day01.to_csv(file_path, index=False, encoding='utf-8')
    print(f"DataFrame successfully saved to: {file_path}")
except Exception as e:
    print(f"Error saving DataFrame to CSV: {e}")
# Out:
# DataFrame successfully saved to: ../data/dietary_data/dietary_nutrient_data_01.csv

# %%
# Now building the URL with the values from the .env file
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

engine = create_engine(url, echo=False) 
df_nutrients_day01.to_sql(name = 'dietary_nutrient_data_01', con=engine, schema='capstone_group_3',if_exists='replace',index=False)
# Out:
# 860

# %% [markdown]
# ## Dietary Nutrient Intake data for Day 02

# %%
# Exporting the Dietary Nutrients intake day  data
df_dietary_nutrient_intake_day_02 = pd.read_sas('F:\Susanna Course\Capstone_data\DR2TOT_L.xpt', format="xport", encoding="utf-8")

# %%
df_dietary_nutrient_intake_day_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8860 entries, 0 to 8859
# Data columns (total 85 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      8860 non-null   float64
#  1   WTDRD1    8860 non-null   float64
#  2   WTDR2D    6754 non-null   float64
#  3   DR2DRSTZ  8860 non-null   float64
#  4   DR2EXMER  5902 non-null   float64
#  5   DRABF     6734 non-null   float64
#  6   DRDINT    6754 non-null   float64
#  7   DR2DBIH   5550 non-null   float64
#  8   DR2DAY    5902 non-null   float64
#  9   DR2LANG   5929 non-null   float64
#  10  DR2MRESP  5879 non-null   float64
#  11  DR2HELP   5876 non-null   float64
#  12  DR2TNUMF  5879 non-null   float64
#  13  DR2STY    5902 non-null   float64
#  14  DR2SKY    1074 non-null   float64
#  15  DR2TKCAL  5830 non-null   float64
#  16  DR2TPROT  5830 non-null   float64
#  17  DR2TCARB  5830 non-null   float64
#  18  DR2TSUGR  5830 non-null   float64
#  19  DR2TFIBE  5830 non-null   float64
#  20  DR2TTFAT  5830 non-null   float64
#  21  DR2TSFAT  5830 non-null   float64
#  22  DR2TMFAT  5830 non-null   float64
#  23  DR2TPFAT  5830 non-null   float64
#  24  DR2TCHOL  5830 non-null   float64
#  25  DR2TATOC  5830 non-null   float64
#  26  DR2TATOA  5830 non-null   float64
#  27  DR2TRET   5830 non-null   float64
#  28  DR2TVARA  5830 non-null   float64
#  29  DR2TACAR  5830 non-null   float64
#  30  DR2TBCAR  5830 non-null   float64
#  31  DR2TCRYP  5830 non-null   float64
#  32  DR2TLYCO  5830 non-null   float64
#  33  DR2TLZ    5830 non-null   float64
#  34  DR2TVB1   5830 non-null   float64
#  35  DR2TVB2   5830 non-null   float64
#  36  DR2TNIAC  5830 non-null   float64
#  37  DR2TVB6   5830 non-null   float64
#  38  DR2TFOLA  5830 non-null   float64
#  39  DR2TFA    5830 non-null   float64
#  40  DR2TFF    5830 non-null   float64
#  41  DR2TFDFE  5830 non-null   float64
#  42  DR2TCHL   5830 non-null   float64
#  43  DR2TVB12  5830 non-null   float64
#  44  DR2TB12A  5830 non-null   float64
#  45  DR2TVC    5830 non-null   float64
#  46  DR2TVD    5830 non-null   float64
#  47  DR2TVK    5830 non-null   float64
#  48  DR2TCALC  5830 non-null   float64
#  49  DR2TPHOS  5830 non-null   float64
#  50  DR2TMAGN  5830 non-null   float64
#  51  DR2TIRON  5830 non-null   float64
#  52  DR2TZINC  5830 non-null   float64
#  53  DR2TCOPP  5830 non-null   float64
#  54  DR2TSODI  5830 non-null   float64
#  55  DR2TPOTA  5830 non-null   float64
#  56  DR2TSELE  5830 non-null   float64
#  57  DR2TCAFF  5830 non-null   float64
#  58  DR2TTHEO  5830 non-null   float64
#  59  DR2TALCO  5830 non-null   float64
#  60  DR2TMOIS  5830 non-null   float64
#  61  DR2TS040  5830 non-null   float64
#  62  DR2TS060  5830 non-null   float64
#  63  DR2TS080  5830 non-null   float64
#  64  DR2TS100  5830 non-null   float64
#  65  DR2TS120  5830 non-null   float64
#  66  DR2TS140  5830 non-null   float64
#  67  DR2TS160  5830 non-null   float64
#  68  DR2TS180  5830 non-null   float64
#  69  DR2TM161  5830 non-null   float64
#  70  DR2TM181  5830 non-null   float64
#  71  DR2TM201  5830 non-null   float64
#  72  DR2TM221  5830 non-null   float64
#  73  DR2TP182  5830 non-null   float64
#  74  DR2TP183  5830 non-null   float64
#  75  DR2TP184  5830 non-null   float64
#  76  DR2TP204  5830 non-null   float64
#  77  DR2TP205  5830 non-null   float64
#  78  DR2TP225  5830 non-null   float64
#  79  DR2TP226  5830 non-null   float64
#  80  DR2_300   5902 non-null   float64
#  81  DR2_320Z  5879 non-null   float64
#  82  DR2_330Z  5879 non-null   float64
#  83  DR2BWATZ  5879 non-null   float64
#  84  DR2TWSZ   5902 non-null   float64
# dtypes: float64(85)
# memory usage: 5.7 MB

# %%
# List of relevant nutrient columns which could potentially be insightful to the research question
nutrient_columns = [
    'SEQN',
    'DR2TKCAL', 'DR2TPROT', 'DR2TCARB','DR2TSUGR','DR2TFIBE', 'DR2TTFAT',
     'DR2TSFAT','DR2TMFAT','DR2TPFAT','DR2TCHOL','DR2TSODI','DR2TPOTA','DR2TMOIS',
    'DR2TVC','DR2TVD','DR2TVK','DR2TCALC'
    ]

# %%
# Filter the dataframe to keep only the relevant columns
df_nutrients_day02 = df_dietary_nutrient_intake_day_02[nutrient_columns]

# %%
# Now changing the data type of 'seqn_no' to int
df_nutrients_day02['SEQN'] = df_nutrients_day02['SEQN'].astype(int)

# %%
# Rename columns
df_nutrients_day02  = df_nutrients_day02.rename(
    columns={'SEQN': 'seqn_no',
             'DR1TKCAL':'energy_kcal','DR1TPROT':'protein_gms','DR1TCARB':'carbohydrate_gms','DR1TTFAT':'total_fats_gms',
             'DR1TSUGR': 'total_sugars_gms','DR1TFIBE':'dietary_fiber_gms','DR1TSFAT':'saturated_fats_gms', 'DR1TMFAT':'mono_saturated_fats_gms',
             'DR1TPFAT':'poly_unsaturated_fats_gms','DR1TCHOL':'cholestrol_gms','DR1TCALC':'calcium_mg',
             'DR1TSODI':'sodium_mg','DR1TPOTA':'potassium_mg','DR1TCAFF':'caffeine_mg','DR1TALCO':'alcohol_gms',
              'DR1TMOIS':'moisture_gms','DR1TVC':'vitaminC_mg','DR1TVD':'vitaminD_mcg','DR1TVK':'vitaK_mcg'})

# %%
df_nutrients_day01.shape
# Out:
# (8860, 18)

# %%
#export as csv

file_path = "../data/dietary_data/dietary_nutrient_data_02.csv" 

try:
    df_nutrients_day02.to_csv(file_path, index=False, encoding='utf-8')
    print(f"DataFrame successfully saved to: {file_path}")
except Exception as e:
    print(f"Error saving DataFrame to CSV: {e}")
# Out:
# DataFrame successfully saved to: ../data/dietary_data/dietary_nutrient_data_02.csv

# %%
# Now building the URL with the values from the .env file
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

engine = create_engine(url, echo=False) 
df_nutrients_day02.to_sql(name = 'dietary_nutrient_data_02', con=engine, schema='capstone_group_3',if_exists='replace',index=False)
# Out:
# 860

# %%
# Now let's avg all the nutrient data on each seqn_no

# Concatenate the two dataframes
df_nutrients = pd.concat([df_nutrients_day01, df_nutrients_day02])

# List of columns that need to be aggregated
nutrient_columns = [
    'energy_kcal', 'protein_gms', 'carbohydrate_gms', 'total_sugars_gms', 
    'dietary_fiber_gms', 'total_fats_gms', 'saturated_fats_gms', 
    'mono_saturated_fats_gms', 'poly_unsaturated_fats_gms', 'cholestrol_gms', 
    'sodium_mg', 'potassium_mg', 'moisture_gms', 'vitaminC_mg', 
    'vitaminD_mcg', 'vitaK_mcg', 'calcium_mg'
]

# Select only the relevant nutrient columns and group by 'seqn_no'
df_nutrients_filtered = df_nutrients[['seqn_no'] + nutrient_columns]

# Group by 'seqn_no' and calculate the mean for all nutrient columns
df_avg_nutrients = df_nutrients_filtered.groupby('seqn_no').agg('mean').reset_index()

# %%
df_avg_nutrients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8860 entries, 0 to 8859
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   seqn_no                    8860 non-null   int64
#  1   energy_kcal                6694 non-null   float64
#  2   protein_gms                6694 non-null   float64
#  3   carbohydrate_gms           6694 non-null   float64
#  4   total_sugars_gms           6694 non-null   float64
#  5   dietary_fiber_gms          6694 non-null   float64
#  6   total_fats_gms             6694 non-null   float64
#  7   saturated_fats_gms         6694 non-null   float64
#  8   mono_saturated_fats_gms    6694 non-null   float64
#  9   poly_unsaturated_fats_gms  6694 non-null   float64
#  10  cholestrol_gms             6694 non-null   float64
#  11  sodium_mg                  6694 non-null   float64
#  12  potassium_mg               6694 non-null   float64
#  13  moisture_gms               6694 non-null   float64
#  14  vitaminC_mg                6694 non-null   float64
#  15  vitaminD_mcg               6694 non-null   float64
#  16  vitaK_mcg                  6694 non-null   float64
#  17  calcium_mg                 6694 non-null   float64
# dtypes: float64(17), int64(1)
# memory usage: 1.2 MB

# %%
df_avg_nutrients

# Define nutrient columns
positive = [
        'dietary_fiber_gms', 'protein_gms', 'poly_unsaturated_fats_gms',
        'mono_saturated_fats_gms', 'potassium_mg', 'vitaminD_mcg',
        'vitaminC_mg', 'vitaK_mcg', 'calcium_mg'
        ]
negative = ['saturated_fats_gms', 'cholestrol_gms', 'sodium_mg', 'total_sugars_gms']
all_nutrients = positive + negative

# Drop rows with missing values in nutrient columns
df_avg_nutrients = df_avg_nutrients.dropna(subset=all_nutrients).copy()

# Normalize using Min-Max scaling
scaler = MinMaxScaler()
normalized = pd.DataFrame(scaler.fit_transform(df_avg_nutrients[all_nutrients]),
                              columns=all_nutrients, index=df_avg_nutrients.index)

# Invert scores for negative nutrients
normalized[negative] = 1 - normalized[negative]

# Calculate nutrient score
df_avg_nutrients['nutrient_score'] = normalized.sum(axis=1)

# %%
# Now building the URL with the values from the .env file
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

engine = create_engine(url, echo=False) 
df_avg_nutrients.to_sql(name = 'dietary_nutrient_avg', con=engine, schema='capstone_group_3',if_exists='replace',index=False)
# Out:
# 694

# %%
# export average for Diet Nutrient data of both days as csv

file_path = "../data/dietary_data/dietary_nutrient_avg_data.csv" 

try:
    df_avg_nutrients.to_csv(file_path, index=False, encoding='utf-8')
    print(f"DataFrame successfully saved to: {file_path}")
except Exception as e:
    print(f"Error saving DataFrame to CSV: {e}")
# Out:
# DataFrame successfully saved to: ../data/dietary_data/dietary_nutrient_avg_data.csv

# %% [markdown]
# # Calculating Hypertesion Risk ratios based on Nutrients

# %%
# Sodium-to-Potassium Ratio:
# - A higher ratio indicates more sodium relative to potassium, which could increases blood pressure risk.
# - A lower ratio (less than 1) suggests a healthier balance, which may help lower hypertension risk.

# Fat Quality Score:
# - This score highlights the balance between saturated fats and unsaturated fats.

# - A higher P/S Ratio score(> 1.0) indicates an healthy fat profile beneficial for heart health and lowering blood pressure.
# - A lower P/S Ratio score(< 1.0) reflects a higher intake of saturated fats, which can contribute to hypertension risks.

# Cholesterol Score:
# - Directly uses the cholesterol value (in g) to gauge cardiovascular health.
# - Elevated cholesterol levels are linked to arterial plaque buildup and increased blood pressure.

# Energy Intake:
# - Represents daily calorie intake (in kcal).
# - Excessive energy intake is associated with weight gain, which is a major risk factor for developing hypertension.

# Vitamin D Values:
# - Imbalances in the vitD could negatively impact vascular health.

# These columns provide a comprehensive view of key nutrients linked to hypertension risk, allowing for deeper analysis of dietary factors influencing blood pressure.

# %%
df_avg_nutrients['potassium_mg'].replace(0, np.nan, inplace=True)
df_avg_nutrients['saturated_fats_gms'].replace(0, np.nan, inplace=True)

# --- 1. Sodium-to-Potassium Ratio ---
df_hypertension_risk['sodium_to_potassium_ratio'] = round(
    df_avg_nutrients['sodium_mg'] / df_avg_nutrients['potassium_mg'], 2
)

# --- 2. Fat Quality Score ---
# Fat quality = (Polyunsaturated fats) / (Saturated fats)
df_hypertension_risk['fat_quality_score'] = round(
    df_avg_nutrients['poly_unsaturated_fats_gms'] / df_avg_nutrients['saturated_fats_gms'], 2
)

# --- 3. Cholesterol Score ---
df_hypertension_risk['cholesterol_score'] = df_avg_nutrients['cholestrol_gms']

# --- 4. Energy Intake (kcal) ---
df_hypertension_risk['energy_intake'] = df_avg_nutrients['energy_kcal']

# --- 5. Vitamin D Score (IU) ---
df_hypertension_risk['vitaminD_IU'] = df_avg_nutrients['vitaminD_mcg'] * 40

# --- Drop rows where all key score columns are null ---
columns_to_check = df_hypertension_risk.columns.drop('seqn_no')
df_hypertension_risk.dropna(subset=columns_to_check, how='all', inplace=True)

# --- Optional: Reset index for cleanliness ---
df_hypertension_risk.reset_index(drop=True, inplace=True)

# --- Final output ---
print(df_hypertension_risk[['seqn_no', 'sodium_to_potassium_ratio', 'fat_quality_score',
                            'cholesterol_score', 'energy_intake', 'vitaminD_IU']])
# Out:
#       seqn_no  sodium_to_potassium_ratio  fat_quality_score  \
# 0      130378                       1.37               0.54
# 1      130379                       1.03               1.76
# 2      130380                       1.37               0.43
# 3      130381                       1.25               0.73
# 4      130382                       1.07               1.61
# ...       ...                        ...                ...
# 2918   142301                       0.47               0.91
# 2919   142302                       1.38               0.97
# 2920   142304                       1.90               1.49
# 2921   142307                       2.37               0.64
# 2922   142310                       1.40               1.59
#
#       cholesterol_score  energy_intake  vitaminD_IU
# 0                 274.0         1740.0          8.0
# 1                 131.0         2741.0         16.0
# 2                 270.0         1995.0        216.0
# 3                 188.0         1676.0        276.0
# 4                  28.0         1222.0         12.0
# ...                 ...            ...          ...
# 2918              221.0         2644.0        288.0
# 2919              143.0         1783.0         24.0
# 2920              632.0         1836.0        260.0
# 2921              778.0         2169.0        232.0
# 2922               37.0         1296.0         32.0
#
# [2923 rows x 6 columns]

# %%
df_hypertension_risk.columns
# Out:
# Index(['seqn_no', 'sodium_to_potassium_ratio', 'fat_quality_score',
#        'cholesterol_score', 'energy_intake', 'vitaminD_IU'],
#       dtype='object')

# %%
# Now building the URL with the values from the .env file
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

engine = create_engine(url, echo=False) 
df_hypertension_risk.to_sql(name = 'hypertension_risk_factor_ratios', con=engine, schema='capstone_group_3',if_exists='replace',index=False)
# Out:
# 923
